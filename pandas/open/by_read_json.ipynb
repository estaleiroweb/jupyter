# %% [markdown]
# # pandas.read_json

# %% [markdown]
# @see https://towardsdatascience.com/how-to-parse-json-data-with-python-pandas-f84fbd0b1025

# %% [markdown]
# https://pandas.pydata.org/docs/reference/
# https://pandas.pydata.org/docs/reference/api/pandas.read_json.html

# %% [markdown]
# pandas.read_json(path_or_buf, orient=None, typ='frame', dtype=None, convert_axes=None, convert_dates=True, keep_default_dates=True, numpy=False, precise_float=False, date_unit=None, encoding=None, encoding_errors='strict', lines=False, chunksize=None, compression='infer', nrows=None, storage_options=None)

# %%
import pandas as pd

# %%
file='file.json'
df=pd.read_json(file)
display(df)
# display(df.to_string())
# Out:
#                                                     id  \
# 0    {'M49': 4, 'ISO-ALPHA-2': 'AF', 'ISO-ALPHA-3':...
# 1    {'M49': 8, 'ISO-ALPHA-2': 'AL', 'ISO-ALPHA-3':...
# 2    {'M49': 12, 'ISO-ALPHA-2': 'DZ', 'ISO-ALPHA-3'...
# 3    {'M49': 20, 'ISO-ALPHA-2': 'AD', 'ISO-ALPHA-3'...
# 4    {'M49': 24, 'ISO-ALPHA-2': 'AO', 'ISO-ALPHA-3'...
# ..                                                 ...
# 188  {'M49': 860, 'ISO-ALPHA-2': 'UZ', 'ISO-ALPHA-3...
# 189  {'M49': 862, 'ISO-ALPHA-2': 'VE', 'ISO-ALPHA-3...
# 190  {'M49': 882, 'ISO-ALPHA-2': 'WS', 'ISO-ALPHA-3...
# 191  {'M49': 887, 'ISO-ALPHA-2': 'YE', 'ISO-ALPHA-3...
# 192  {'M49': 894, 'ISO-ALPHA-2': 'ZM', 'ISO-ALPHA-3...
#
#                                      nome  \
# 0                             Afeganistão
# 1                                 Albânia
# 2                                 Argélia
# 3                                 Andorra
# 4                                  Angola
# ..                                    ...
# 188                           Uzbequistão
# 189  Venezuela (República Bolivariana da)
# 190                                 Samoa
# 191                                 Iêmen
# 192                                Zâmbia
#
#                                   regiao-intermediaria  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4        {'id': {'M49': 17}, 'nome': 'África central'}
# ..                                                 ...
# 188                                               None
# 189       {'id': {'M49': 5}, 'nome': 'América do sul'}
# 190                                               None
# 191                                               None
# 192  {'id': {'M49': 14}, 'nome': 'África oriental (...
#
#                                             sub-regiao
# 0    {'id': {'M49': 34}, 'nome': 'Ásia meridional (...
# 1    {'id': {'M49': 39}, 'nome': 'Europa meridional...
# 2    {'id': {'M49': 15}, 'nome': 'África setentrion...
# 3    {'id': {'M49': 39}, 'nome': 'Europa meridional...
# 4    {'id': {'M49': 202}, 'nome': 'África subsaaria...
# ..                                                 ...
# 188  {'id': {'M49': 143}, 'nome': 'Ásia central', '...
# 189  {'id': {'M49': 419}, 'nome': 'América Latina e...
# 190  {'id': {'M49': 61}, 'nome': 'Polinésia', 'regi...
# 191  {'id': {'M49': 145}, 'nome': 'Ásia ocidental  ...
# 192  {'id': {'M49': 202}, 'nome': 'África subsaaria...
#
# [193 rows x 4 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    193 non-null    object
#  1   nome                  193 non-null    object
#  2   regiao-intermediaria  81 non-null     object
#  3   sub-regiao            193 non-null    object
# dtypes: object(4)
# memory usage: 6.2+ KB
# None

# %%
display(df.head())
# Out:
#                                                   id         nome  \
# 0  {'M49': 4, 'ISO-ALPHA-2': 'AF', 'ISO-ALPHA-3':...  Afeganistão
# 1  {'M49': 8, 'ISO-ALPHA-2': 'AL', 'ISO-ALPHA-3':...      Albânia
# 2  {'M49': 12, 'ISO-ALPHA-2': 'DZ', 'ISO-ALPHA-3'...      Argélia
# 3  {'M49': 20, 'ISO-ALPHA-2': 'AD', 'ISO-ALPHA-3'...      Andorra
# 4  {'M49': 24, 'ISO-ALPHA-2': 'AO', 'ISO-ALPHA-3'...       Angola
#
#                             regiao-intermediaria  \
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4  {'id': {'M49': 17}, 'nome': 'África central'}
#
#                                           sub-regiao
# 0  {'id': {'M49': 34}, 'nome': 'Ásia meridional (...
# 1  {'id': {'M49': 39}, 'nome': 'Europa meridional...
# 2  {'id': {'M49': 15}, 'nome': 'África setentrion...
# 3  {'id': {'M49': 39}, 'nome': 'Europa meridional...
# 4  {'id': {'M49': 202}, 'nome': 'África subsaaria...

# %%
display(df.tail())
# Out:
#                                                     id  \
# 188  {'M49': 860, 'ISO-ALPHA-2': 'UZ', 'ISO-ALPHA-3...
# 189  {'M49': 862, 'ISO-ALPHA-2': 'VE', 'ISO-ALPHA-3...
# 190  {'M49': 882, 'ISO-ALPHA-2': 'WS', 'ISO-ALPHA-3...
# 191  {'M49': 887, 'ISO-ALPHA-2': 'YE', 'ISO-ALPHA-3...
# 192  {'M49': 894, 'ISO-ALPHA-2': 'ZM', 'ISO-ALPHA-3...
#
#                                      nome  \
# 188                           Uzbequistão
# 189  Venezuela (República Bolivariana da)
# 190                                 Samoa
# 191                                 Iêmen
# 192                                Zâmbia
#
#                                   regiao-intermediaria  \
# 188                                               None
# 189       {'id': {'M49': 5}, 'nome': 'América do sul'}
# 190                                               None
# 191                                               None
# 192  {'id': {'M49': 14}, 'nome': 'África oriental (...
#
#                                             sub-regiao
# 188  {'id': {'M49': 143}, 'nome': 'Ásia central', '...
# 189  {'id': {'M49': 419}, 'nome': 'América Latina e...
# 190  {'id': {'M49': 61}, 'nome': 'Polinésia', 'regi...
# 191  {'id': {'M49': 145}, 'nome': 'Ásia ocidental  ...
# 192  {'id': {'M49': 202}, 'nome': 'África subsaaria...

# %%
print(df.to_string())
# Out:
#                                                           id                                            nome                                               regiao-intermediaria                                                                                                               sub-regiao
# 0      {'M49': 4, 'ISO-ALPHA-2': 'AF', 'ISO-ALPHA-3': 'AFG'}                                     Afeganistão                                                               None             {'id': {'M49': 34}, 'nome': 'Ásia meridional (Sul da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 1      {'M49': 8, 'ISO-ALPHA-2': 'AL', 'ISO-ALPHA-3': 'ALB'}                                         Albânia                                                               None      {'id': {'M49': 39}, 'nome': 'Europa meridional  (Sul da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 2     {'M49': 12, 'ISO-ALPHA-2': 'DZ', 'ISO-ALPHA-3': 'DZA'}                                         Argélia                                                               None     {'id': {'M49': 15}, 'nome': 'África setentrional (Norte da África)', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 3     {'M49': 20, 'ISO-ALPHA-2': 'AD', 'ISO-ALPHA-3': 'AND'}                                         Andorra                                                               None      {'id': {'M49': 39}, 'nome': 'Europa meridional  (Sul da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 4     {'M49': 24, 'ISO-ALPHA-2': 'AO', 'ISO-ALPHA-3': 'AGO'}                                          Angola                      {'id': {'M49': 17}, 'nome': 'África central'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 5     {'M49': 28, 'ISO-ALPHA-2': 'AG', 'ISO-ALPHA-3': 'ATG'}                               Antígua e Barbuda                              {'id': {'M49': 29}, 'nome': 'Caribe'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 6     {'M49': 31, 'ISO-ALPHA-2': 'AZ', 'ISO-ALPHA-3': 'AZE'}                                      Azerbaijão                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 7     {'M49': 32, 'ISO-ALPHA-2': 'AR', 'ISO-ALPHA-3': 'ARG'}                                       Argentina                       {'id': {'M49': 5}, 'nome': 'América do sul'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 8     {'M49': 36, 'ISO-ALPHA-2': 'AU', 'ISO-ALPHA-3': 'AUS'}                                       Austrália                                                               None                {'id': {'M49': 53}, 'nome': 'Austrália e Nova Zelândia', 'regiao': {'id': {'M49': 9}, 'nome': 'Oceania'}}
# 9     {'M49': 40, 'ISO-ALPHA-2': 'AT', 'ISO-ALPHA-3': 'AUT'}                                         Áustria                                                               None     {'id': {'M49': 155}, 'nome': 'Europa ocidental (Oeste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 10    {'M49': 44, 'ISO-ALPHA-2': 'BS', 'ISO-ALPHA-3': 'BHS'}                                         Bahamas                              {'id': {'M49': 29}, 'nome': 'Caribe'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 11    {'M49': 48, 'ISO-ALPHA-2': 'BH', 'ISO-ALPHA-3': 'BHR'}                                          Barein                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 12    {'M49': 50, 'ISO-ALPHA-2': 'BD', 'ISO-ALPHA-3': 'BGD'}                                      Bangladesh                                                               None             {'id': {'M49': 34}, 'nome': 'Ásia meridional (Sul da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 13    {'M49': 51, 'ISO-ALPHA-2': 'AM', 'ISO-ALPHA-3': 'ARM'}                                         Armênia                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 14    {'M49': 52, 'ISO-ALPHA-2': 'BB', 'ISO-ALPHA-3': 'BRB'}                                        Barbados                              {'id': {'M49': 29}, 'nome': 'Caribe'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 15    {'M49': 56, 'ISO-ALPHA-2': 'BE', 'ISO-ALPHA-3': 'BEL'}                                         Bélgica                                                               None     {'id': {'M49': 155}, 'nome': 'Europa ocidental (Oeste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 16    {'M49': 64, 'ISO-ALPHA-2': 'BT', 'ISO-ALPHA-3': 'BTN'}                                           Butão                                                               None             {'id': {'M49': 34}, 'nome': 'Ásia meridional (Sul da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 17    {'M49': 68, 'ISO-ALPHA-2': 'BO', 'ISO-ALPHA-3': 'BOL'}               Bolívia (Estado Plurinacional da)                       {'id': {'M49': 5}, 'nome': 'América do sul'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 18    {'M49': 70, 'ISO-ALPHA-2': 'BA', 'ISO-ALPHA-3': 'BIH'}                            Bósnia e Herzegovina                                                               None      {'id': {'M49': 39}, 'nome': 'Europa meridional  (Sul da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 19    {'M49': 72, 'ISO-ALPHA-2': 'BW', 'ISO-ALPHA-3': 'BWA'}                                        Botsuana   {'id': {'M49': 18}, 'nome': 'África meridional (Sul da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 20    {'M49': 76, 'ISO-ALPHA-2': 'BR', 'ISO-ALPHA-3': 'BRA'}                                          Brasil                       {'id': {'M49': 5}, 'nome': 'América do sul'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 21    {'M49': 84, 'ISO-ALPHA-2': 'BZ', 'ISO-ALPHA-3': 'BLZ'}                                          Belize                     {'id': {'M49': 13}, 'nome': 'América central'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 22    {'M49': 90, 'ISO-ALPHA-2': 'SB', 'ISO-ALPHA-3': 'SLB'}                                   Ilhas Salomão                                                               None                                {'id': {'M49': 54}, 'nome': 'Melanésia', 'regiao': {'id': {'M49': 9}, 'nome': 'Oceania'}}
# 23    {'M49': 96, 'ISO-ALPHA-2': 'BN', 'ISO-ALPHA-3': 'BRN'}                                          Brunei                                                               None                           {'id': {'M49': 35}, 'nome': 'Sudeste da Ásia', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 24   {'M49': 100, 'ISO-ALPHA-2': 'BG', 'ISO-ALPHA-3': 'BGR'}                                        Bulgária                                                               None      {'id': {'M49': 151}, 'nome': 'Europa oriental (Leste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 25   {'M49': 104, 'ISO-ALPHA-2': 'MM', 'ISO-ALPHA-3': 'MMR'}                                         Mianmar                                                               None                           {'id': {'M49': 35}, 'nome': 'Sudeste da Ásia', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 26   {'M49': 108, 'ISO-ALPHA-2': 'BI', 'ISO-ALPHA-3': 'BDI'}                                         Burundi   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 27   {'M49': 112, 'ISO-ALPHA-2': 'BY', 'ISO-ALPHA-3': 'BLR'}                                         Belarus                                                               None      {'id': {'M49': 151}, 'nome': 'Europa oriental (Leste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 28   {'M49': 116, 'ISO-ALPHA-2': 'KH', 'ISO-ALPHA-3': 'KHM'}                                         Camboja                                                               None                           {'id': {'M49': 35}, 'nome': 'Sudeste da Ásia', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 29   {'M49': 120, 'ISO-ALPHA-2': 'CM', 'ISO-ALPHA-3': 'CMR'}                                        Camarões                      {'id': {'M49': 17}, 'nome': 'África central'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 30   {'M49': 124, 'ISO-ALPHA-2': 'CA', 'ISO-ALPHA-3': 'CAN'}                                          Canadá                                                               None                        {'id': {'M49': 21}, 'nome': 'América do Norte', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 31   {'M49': 132, 'ISO-ALPHA-2': 'CV', 'ISO-ALPHA-3': 'CPV'}                                      Cabo Verde  {'id': {'M49': 11}, 'nome': 'África ocidental (Oeste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 32   {'M49': 140, 'ISO-ALPHA-2': 'CF', 'ISO-ALPHA-3': 'CAF'}                       República Centro-Africana                      {'id': {'M49': 17}, 'nome': 'África central'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 33   {'M49': 144, 'ISO-ALPHA-2': 'LK', 'ISO-ALPHA-3': 'LKA'}                                       Sri Lanka                                                               None             {'id': {'M49': 34}, 'nome': 'Ásia meridional (Sul da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 34   {'M49': 148, 'ISO-ALPHA-2': 'TD', 'ISO-ALPHA-3': 'TCD'}                                           Chade                      {'id': {'M49': 17}, 'nome': 'África central'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 35   {'M49': 152, 'ISO-ALPHA-2': 'CL', 'ISO-ALPHA-3': 'CHL'}                                           Chile                       {'id': {'M49': 5}, 'nome': 'América do sul'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 36   {'M49': 156, 'ISO-ALPHA-2': 'CN', 'ISO-ALPHA-3': 'CHN'}                                           China                                                               None             {'id': {'M49': 30}, 'nome': 'Ásia oriental (Leste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 37   {'M49': 170, 'ISO-ALPHA-2': 'CO', 'ISO-ALPHA-3': 'COL'}                                        Colômbia                       {'id': {'M49': 5}, 'nome': 'América do sul'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 38   {'M49': 174, 'ISO-ALPHA-2': 'KM', 'ISO-ALPHA-3': 'COM'}                                         Comores   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 39   {'M49': 178, 'ISO-ALPHA-2': 'CG', 'ISO-ALPHA-3': 'COG'}                                           Congo                      {'id': {'M49': 17}, 'nome': 'África central'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 40   {'M49': 180, 'ISO-ALPHA-2': 'CD', 'ISO-ALPHA-3': 'COD'}                  República Democrática do Congo                      {'id': {'M49': 17}, 'nome': 'África central'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 41   {'M49': 188, 'ISO-ALPHA-2': 'CR', 'ISO-ALPHA-3': 'CRI'}                                      Costa Rica                     {'id': {'M49': 13}, 'nome': 'América central'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 42   {'M49': 191, 'ISO-ALPHA-2': 'HR', 'ISO-ALPHA-3': 'HRV'}                                         Croácia                                                               None      {'id': {'M49': 39}, 'nome': 'Europa meridional  (Sul da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 43   {'M49': 192, 'ISO-ALPHA-2': 'CU', 'ISO-ALPHA-3': 'CUB'}                                            Cuba                              {'id': {'M49': 29}, 'nome': 'Caribe'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 44   {'M49': 196, 'ISO-ALPHA-2': 'CY', 'ISO-ALPHA-3': 'CYP'}                                          Chipre                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 45   {'M49': 203, 'ISO-ALPHA-2': 'CZ', 'ISO-ALPHA-3': 'CZE'}                                República Tcheca                                                               None      {'id': {'M49': 151}, 'nome': 'Europa oriental (Leste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 46   {'M49': 204, 'ISO-ALPHA-2': 'BJ', 'ISO-ALPHA-3': 'BEN'}                                           Benin  {'id': {'M49': 11}, 'nome': 'África ocidental (Oeste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 47   {'M49': 208, 'ISO-ALPHA-2': 'DK', 'ISO-ALPHA-3': 'DNK'}                                       Dinamarca                                                               None  {'id': {'M49': 154}, 'nome': 'Europa setentrional (Norte da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 48   {'M49': 212, 'ISO-ALPHA-2': 'DM', 'ISO-ALPHA-3': 'DMA'}                                        Dominica                              {'id': {'M49': 29}, 'nome': 'Caribe'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 49   {'M49': 214, 'ISO-ALPHA-2': 'DO', 'ISO-ALPHA-3': 'DOM'}                            República Dominicana                              {'id': {'M49': 29}, 'nome': 'Caribe'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 50   {'M49': 218, 'ISO-ALPHA-2': 'EC', 'ISO-ALPHA-3': 'ECU'}                                         Equador                       {'id': {'M49': 5}, 'nome': 'América do sul'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 51   {'M49': 222, 'ISO-ALPHA-2': 'SV', 'ISO-ALPHA-3': 'SLV'}                                     El Salvador                     {'id': {'M49': 13}, 'nome': 'América central'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 52   {'M49': 226, 'ISO-ALPHA-2': 'GQ', 'ISO-ALPHA-3': 'GNQ'}                                Guiné Equatorial                      {'id': {'M49': 17}, 'nome': 'África central'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 53   {'M49': 231, 'ISO-ALPHA-2': 'ET', 'ISO-ALPHA-3': 'ETH'}                                         Etiópia   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 54   {'M49': 232, 'ISO-ALPHA-2': 'ER', 'ISO-ALPHA-3': 'ERI'}                                        Eritreia   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 55   {'M49': 233, 'ISO-ALPHA-2': 'EE', 'ISO-ALPHA-3': 'EST'}                                         Estônia                                                               None  {'id': {'M49': 154}, 'nome': 'Europa setentrional (Norte da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 56   {'M49': 242, 'ISO-ALPHA-2': 'FJ', 'ISO-ALPHA-3': 'FJI'}                                            Fiji                                                               None                                {'id': {'M49': 54}, 'nome': 'Melanésia', 'regiao': {'id': {'M49': 9}, 'nome': 'Oceania'}}
# 57   {'M49': 246, 'ISO-ALPHA-2': 'FI', 'ISO-ALPHA-3': 'FIN'}                                       Finlândia                                                               None  {'id': {'M49': 154}, 'nome': 'Europa setentrional (Norte da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 58   {'M49': 250, 'ISO-ALPHA-2': 'FR', 'ISO-ALPHA-3': 'FRA'}                                          França                                                               None     {'id': {'M49': 155}, 'nome': 'Europa ocidental (Oeste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 59   {'M49': 262, 'ISO-ALPHA-2': 'DJ', 'ISO-ALPHA-3': 'DJI'}                                        Djibouti   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 60   {'M49': 266, 'ISO-ALPHA-2': 'GA', 'ISO-ALPHA-3': 'GAB'}                                           Gabão                      {'id': {'M49': 17}, 'nome': 'África central'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 61   {'M49': 268, 'ISO-ALPHA-2': 'GE', 'ISO-ALPHA-3': 'GEO'}                                         Geórgia                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 62   {'M49': 270, 'ISO-ALPHA-2': 'GM', 'ISO-ALPHA-3': 'GMB'}                                          Gâmbia  {'id': {'M49': 11}, 'nome': 'África ocidental (Oeste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 63   {'M49': 276, 'ISO-ALPHA-2': 'DE', 'ISO-ALPHA-3': 'DEU'}                                        Alemanha                                                               None     {'id': {'M49': 155}, 'nome': 'Europa ocidental (Oeste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 64   {'M49': 288, 'ISO-ALPHA-2': 'GH', 'ISO-ALPHA-3': 'GHA'}                                            Gana  {'id': {'M49': 11}, 'nome': 'África ocidental (Oeste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 65   {'M49': 296, 'ISO-ALPHA-2': 'KI', 'ISO-ALPHA-3': 'KIR'}                                        Kiribati                                                               None                               {'id': {'M49': 57}, 'nome': 'Micronésia', 'regiao': {'id': {'M49': 9}, 'nome': 'Oceania'}}
# 66   {'M49': 300, 'ISO-ALPHA-2': 'GR', 'ISO-ALPHA-3': 'GRC'}                                          Grécia                                                               None      {'id': {'M49': 39}, 'nome': 'Europa meridional  (Sul da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 67   {'M49': 308, 'ISO-ALPHA-2': 'GD', 'ISO-ALPHA-3': 'GRD'}                                         Granada                              {'id': {'M49': 29}, 'nome': 'Caribe'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 68   {'M49': 320, 'ISO-ALPHA-2': 'GT', 'ISO-ALPHA-3': 'GTM'}                                       Guatemala                     {'id': {'M49': 13}, 'nome': 'América central'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 69   {'M49': 324, 'ISO-ALPHA-2': 'GN', 'ISO-ALPHA-3': 'GIN'}                                           Guiné  {'id': {'M49': 11}, 'nome': 'África ocidental (Oeste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 70   {'M49': 328, 'ISO-ALPHA-2': 'GY', 'ISO-ALPHA-3': 'GUY'}                                          Guiana                       {'id': {'M49': 5}, 'nome': 'América do sul'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 71   {'M49': 332, 'ISO-ALPHA-2': 'HT', 'ISO-ALPHA-3': 'HTI'}                                           Haiti                              {'id': {'M49': 29}, 'nome': 'Caribe'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 72   {'M49': 340, 'ISO-ALPHA-2': 'HN', 'ISO-ALPHA-3': 'HND'}                                        Honduras                     {'id': {'M49': 13}, 'nome': 'América central'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 73   {'M49': 348, 'ISO-ALPHA-2': 'HU', 'ISO-ALPHA-3': 'HUN'}                                         Hungria                                                               None      {'id': {'M49': 151}, 'nome': 'Europa oriental (Leste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 74   {'M49': 352, 'ISO-ALPHA-2': 'IS', 'ISO-ALPHA-3': 'ISL'}                                        Islândia                                                               None  {'id': {'M49': 154}, 'nome': 'Europa setentrional (Norte da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 75   {'M49': 356, 'ISO-ALPHA-2': 'IN', 'ISO-ALPHA-3': 'IND'}                                           Índia                                                               None             {'id': {'M49': 34}, 'nome': 'Ásia meridional (Sul da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 76   {'M49': 360, 'ISO-ALPHA-2': 'ID', 'ISO-ALPHA-3': 'IDN'}                                       Indonésia                                                               None                           {'id': {'M49': 35}, 'nome': 'Sudeste da Ásia', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 77   {'M49': 364, 'ISO-ALPHA-2': 'IR', 'ISO-ALPHA-3': 'IRN'}                     Irã (República Islâmica do)                                                               None             {'id': {'M49': 34}, 'nome': 'Ásia meridional (Sul da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 78   {'M49': 368, 'ISO-ALPHA-2': 'IQ', 'ISO-ALPHA-3': 'IRQ'}                                          Iraque                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 79   {'M49': 372, 'ISO-ALPHA-2': 'IE', 'ISO-ALPHA-3': 'IRL'}                                         Irlanda                                                               None  {'id': {'M49': 154}, 'nome': 'Europa setentrional (Norte da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 80   {'M49': 376, 'ISO-ALPHA-2': 'IL', 'ISO-ALPHA-3': 'ISR'}                                          Israel                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 81   {'M49': 380, 'ISO-ALPHA-2': 'IT', 'ISO-ALPHA-3': 'ITA'}                                          Itália                                                               None      {'id': {'M49': 39}, 'nome': 'Europa meridional  (Sul da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 82   {'M49': 384, 'ISO-ALPHA-2': 'CI', 'ISO-ALPHA-3': 'CIV'}                                 Costa do Marfim  {'id': {'M49': 11}, 'nome': 'África ocidental (Oeste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 83   {'M49': 388, 'ISO-ALPHA-2': 'JM', 'ISO-ALPHA-3': 'JAM'}                                         Jamaica                              {'id': {'M49': 29}, 'nome': 'Caribe'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 84   {'M49': 392, 'ISO-ALPHA-2': 'JP', 'ISO-ALPHA-3': 'JPN'}                                           Japão                                                               None             {'id': {'M49': 30}, 'nome': 'Ásia oriental (Leste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 85   {'M49': 398, 'ISO-ALPHA-2': 'KZ', 'ISO-ALPHA-3': 'KAZ'}                                     Cazaquistão                                                               None                             {'id': {'M49': 143}, 'nome': 'Ásia central', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 86   {'M49': 400, 'ISO-ALPHA-2': 'JO', 'ISO-ALPHA-3': 'JOR'}                                        Jordânia                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 87   {'M49': 404, 'ISO-ALPHA-2': 'KE', 'ISO-ALPHA-3': 'KEN'}                                          Quênia   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 88   {'M49': 408, 'ISO-ALPHA-2': 'KP', 'ISO-ALPHA-3': 'PRK'}         República Popular Democrática da Coreia                                                               None             {'id': {'M49': 30}, 'nome': 'Ásia oriental (Leste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 89   {'M49': 410, 'ISO-ALPHA-2': 'KR', 'ISO-ALPHA-3': 'KOR'}                             República da Coreia                                                               None             {'id': {'M49': 30}, 'nome': 'Ásia oriental (Leste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 90   {'M49': 414, 'ISO-ALPHA-2': 'KW', 'ISO-ALPHA-3': 'KWT'}                                          Kuwait                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 91   {'M49': 417, 'ISO-ALPHA-2': 'KG', 'ISO-ALPHA-3': 'KGZ'}                                     Quirguistão                                                               None                             {'id': {'M49': 143}, 'nome': 'Ásia central', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 92   {'M49': 418, 'ISO-ALPHA-2': 'LA', 'ISO-ALPHA-3': 'LAO'}           República Democrática Popular do Laos                                                               None                           {'id': {'M49': 35}, 'nome': 'Sudeste da Ásia', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 93   {'M49': 422, 'ISO-ALPHA-2': 'LB', 'ISO-ALPHA-3': 'LBN'}                                          Líbano                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 94   {'M49': 426, 'ISO-ALPHA-2': 'LS', 'ISO-ALPHA-3': 'LSO'}                                          Lesoto   {'id': {'M49': 18}, 'nome': 'África meridional (Sul da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 95   {'M49': 428, 'ISO-ALPHA-2': 'LV', 'ISO-ALPHA-3': 'LVA'}                                         Letônia                                                               None  {'id': {'M49': 154}, 'nome': 'Europa setentrional (Norte da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 96   {'M49': 430, 'ISO-ALPHA-2': 'LR', 'ISO-ALPHA-3': 'LBR'}                                         Libéria  {'id': {'M49': 11}, 'nome': 'África ocidental (Oeste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 97   {'M49': 434, 'ISO-ALPHA-2': 'LY', 'ISO-ALPHA-3': 'LBY'}                                           Líbia                                                               None     {'id': {'M49': 15}, 'nome': 'África setentrional (Norte da África)', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 98   {'M49': 438, 'ISO-ALPHA-2': 'LI', 'ISO-ALPHA-3': 'LIE'}                                   Liechtenstein                                                               None     {'id': {'M49': 155}, 'nome': 'Europa ocidental (Oeste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 99   {'M49': 440, 'ISO-ALPHA-2': 'LT', 'ISO-ALPHA-3': 'LTU'}                                        Lituânia                                                               None  {'id': {'M49': 154}, 'nome': 'Europa setentrional (Norte da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 100  {'M49': 442, 'ISO-ALPHA-2': 'LU', 'ISO-ALPHA-3': 'LUX'}                                      Luxemburgo                                                               None     {'id': {'M49': 155}, 'nome': 'Europa ocidental (Oeste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 101  {'M49': 450, 'ISO-ALPHA-2': 'MG', 'ISO-ALPHA-3': 'MDG'}                                      Madagascar   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 102  {'M49': 454, 'ISO-ALPHA-2': 'MW', 'ISO-ALPHA-3': 'MWI'}                                          Malauí   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 103  {'M49': 458, 'ISO-ALPHA-2': 'MY', 'ISO-ALPHA-3': 'MYS'}                                         Malásia                                                               None                           {'id': {'M49': 35}, 'nome': 'Sudeste da Ásia', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 104  {'M49': 462, 'ISO-ALPHA-2': 'MV', 'ISO-ALPHA-3': 'MDV'}                                        Maldivas                                                               None             {'id': {'M49': 34}, 'nome': 'Ásia meridional (Sul da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 105  {'M49': 466, 'ISO-ALPHA-2': 'ML', 'ISO-ALPHA-3': 'MLI'}                                            Mali  {'id': {'M49': 11}, 'nome': 'África ocidental (Oeste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 106  {'M49': 470, 'ISO-ALPHA-2': 'MT', 'ISO-ALPHA-3': 'MLT'}                                           Malta                                                               None      {'id': {'M49': 39}, 'nome': 'Europa meridional  (Sul da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 107  {'M49': 478, 'ISO-ALPHA-2': 'MR', 'ISO-ALPHA-3': 'MRT'}                                      Mauritânia  {'id': {'M49': 11}, 'nome': 'África ocidental (Oeste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 108  {'M49': 480, 'ISO-ALPHA-2': 'MU', 'ISO-ALPHA-3': 'MUS'}                                        Maurício   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 109  {'M49': 484, 'ISO-ALPHA-2': 'MX', 'ISO-ALPHA-3': 'MEX'}                                          México                     {'id': {'M49': 13}, 'nome': 'América central'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 110  {'M49': 492, 'ISO-ALPHA-2': 'MC', 'ISO-ALPHA-3': 'MCO'}                                          Mônaco                                                               None     {'id': {'M49': 155}, 'nome': 'Europa ocidental (Oeste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 111  {'M49': 496, 'ISO-ALPHA-2': 'MN', 'ISO-ALPHA-3': 'MNG'}                                        Mongólia                                                               None             {'id': {'M49': 30}, 'nome': 'Ásia oriental (Leste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 112  {'M49': 498, 'ISO-ALPHA-2': 'MD', 'ISO-ALPHA-3': 'MDA'}                         Moldávia (República da)                                                               None      {'id': {'M49': 151}, 'nome': 'Europa oriental (Leste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 113  {'M49': 499, 'ISO-ALPHA-2': 'ME', 'ISO-ALPHA-3': 'MNE'}                                      Montenegro                                                               None      {'id': {'M49': 39}, 'nome': 'Europa meridional  (Sul da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 114  {'M49': 504, 'ISO-ALPHA-2': 'MA', 'ISO-ALPHA-3': 'MAR'}                                        Marrocos                                                               None     {'id': {'M49': 15}, 'nome': 'África setentrional (Norte da África)', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 115  {'M49': 508, 'ISO-ALPHA-2': 'MZ', 'ISO-ALPHA-3': 'MOZ'}                                      Moçambique   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 116  {'M49': 512, 'ISO-ALPHA-2': 'OM', 'ISO-ALPHA-3': 'OMN'}                                             Omã                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 117  {'M49': 516, 'ISO-ALPHA-2': 'NA', 'ISO-ALPHA-3': 'NAM'}                                         Namíbia   {'id': {'M49': 18}, 'nome': 'África meridional (Sul da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 118  {'M49': 520, 'ISO-ALPHA-2': 'NR', 'ISO-ALPHA-3': 'NRU'}                                           Nauru                                                               None                               {'id': {'M49': 57}, 'nome': 'Micronésia', 'regiao': {'id': {'M49': 9}, 'nome': 'Oceania'}}
# 119  {'M49': 524, 'ISO-ALPHA-2': 'NP', 'ISO-ALPHA-3': 'NPL'}                                           Nepal                                                               None             {'id': {'M49': 34}, 'nome': 'Ásia meridional (Sul da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 120  {'M49': 528, 'ISO-ALPHA-2': 'NL', 'ISO-ALPHA-3': 'NLD'}                                         Holanda                                                               None     {'id': {'M49': 155}, 'nome': 'Europa ocidental (Oeste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 121  {'M49': 548, 'ISO-ALPHA-2': 'VU', 'ISO-ALPHA-3': 'VUT'}                                         Vanuatu                                                               None                                {'id': {'M49': 54}, 'nome': 'Melanésia', 'regiao': {'id': {'M49': 9}, 'nome': 'Oceania'}}
# 122  {'M49': 554, 'ISO-ALPHA-2': 'NZ', 'ISO-ALPHA-3': 'NZL'}                                   Nova Zelândia                                                               None                {'id': {'M49': 53}, 'nome': 'Austrália e Nova Zelândia', 'regiao': {'id': {'M49': 9}, 'nome': 'Oceania'}}
# 123  {'M49': 558, 'ISO-ALPHA-2': 'NI', 'ISO-ALPHA-3': 'NIC'}                                       Nicarágua                     {'id': {'M49': 13}, 'nome': 'América central'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 124  {'M49': 562, 'ISO-ALPHA-2': 'NE', 'ISO-ALPHA-3': 'NER'}                                           Niger  {'id': {'M49': 11}, 'nome': 'África ocidental (Oeste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 125  {'M49': 566, 'ISO-ALPHA-2': 'NG', 'ISO-ALPHA-3': 'NGA'}                                         Nigéria  {'id': {'M49': 11}, 'nome': 'África ocidental (Oeste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 126  {'M49': 578, 'ISO-ALPHA-2': 'NO', 'ISO-ALPHA-3': 'NOR'}                                         Noruega                                                               None  {'id': {'M49': 154}, 'nome': 'Europa setentrional (Norte da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 127  {'M49': 583, 'ISO-ALPHA-2': 'FM', 'ISO-ALPHA-3': 'FSM'}               Micronésia (Estados Federados da)                                                               None                               {'id': {'M49': 57}, 'nome': 'Micronésia', 'regiao': {'id': {'M49': 9}, 'nome': 'Oceania'}}
# 128  {'M49': 584, 'ISO-ALPHA-2': 'MH', 'ISO-ALPHA-3': 'MHL'}                                  Ilhas Marshall                                                               None                               {'id': {'M49': 57}, 'nome': 'Micronésia', 'regiao': {'id': {'M49': 9}, 'nome': 'Oceania'}}
# 129  {'M49': 585, 'ISO-ALPHA-2': 'PW', 'ISO-ALPHA-3': 'PLW'}                                           Palau                                                               None                               {'id': {'M49': 57}, 'nome': 'Micronésia', 'regiao': {'id': {'M49': 9}, 'nome': 'Oceania'}}
# 130  {'M49': 586, 'ISO-ALPHA-2': 'PK', 'ISO-ALPHA-3': 'PAK'}                                       Paquistão                                                               None             {'id': {'M49': 34}, 'nome': 'Ásia meridional (Sul da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 131  {'M49': 591, 'ISO-ALPHA-2': 'PA', 'ISO-ALPHA-3': 'PAN'}                                          Panamá                     {'id': {'M49': 13}, 'nome': 'América central'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 132  {'M49': 598, 'ISO-ALPHA-2': 'PG', 'ISO-ALPHA-3': 'PNG'}                                Papua Nova Guiné                                                               None                                {'id': {'M49': 54}, 'nome': 'Melanésia', 'regiao': {'id': {'M49': 9}, 'nome': 'Oceania'}}
# 133  {'M49': 600, 'ISO-ALPHA-2': 'PY', 'ISO-ALPHA-3': 'PRY'}                                        Paraguai                       {'id': {'M49': 5}, 'nome': 'América do sul'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 134  {'M49': 604, 'ISO-ALPHA-2': 'PE', 'ISO-ALPHA-3': 'PER'}                                            Peru                       {'id': {'M49': 5}, 'nome': 'América do sul'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 135  {'M49': 608, 'ISO-ALPHA-2': 'PH', 'ISO-ALPHA-3': 'PHL'}                                       Filipinas                                                               None                           {'id': {'M49': 35}, 'nome': 'Sudeste da Ásia', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 136  {'M49': 616, 'ISO-ALPHA-2': 'PL', 'ISO-ALPHA-3': 'POL'}                                         Polônia                                                               None      {'id': {'M49': 151}, 'nome': 'Europa oriental (Leste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 137  {'M49': 620, 'ISO-ALPHA-2': 'PT', 'ISO-ALPHA-3': 'PRT'}                                        Portugal                                                               None      {'id': {'M49': 39}, 'nome': 'Europa meridional  (Sul da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 138  {'M49': 624, 'ISO-ALPHA-2': 'GW', 'ISO-ALPHA-3': 'GNB'}                                    Guiné-Bissau  {'id': {'M49': 11}, 'nome': 'África ocidental (Oeste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 139  {'M49': 626, 'ISO-ALPHA-2': 'TL', 'ISO-ALPHA-3': 'TLS'}                                     Timor-Leste                                                               None                           {'id': {'M49': 35}, 'nome': 'Sudeste da Ásia', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 140  {'M49': 634, 'ISO-ALPHA-2': 'QA', 'ISO-ALPHA-3': 'QAT'}                                           Catar                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 141  {'M49': 642, 'ISO-ALPHA-2': 'RO', 'ISO-ALPHA-3': 'ROU'}                                         Romênia                                                               None      {'id': {'M49': 151}, 'nome': 'Europa oriental (Leste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 142  {'M49': 643, 'ISO-ALPHA-2': 'RU', 'ISO-ALPHA-3': 'RUS'}                             Federação da Rússia                                                               None      {'id': {'M49': 151}, 'nome': 'Europa oriental (Leste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 143  {'M49': 646, 'ISO-ALPHA-2': 'RW', 'ISO-ALPHA-3': 'RWA'}                                          Ruanda   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 144  {'M49': 659, 'ISO-ALPHA-2': 'KN', 'ISO-ALPHA-3': 'KNA'}                           São Cristóvão e Nevis                              {'id': {'M49': 29}, 'nome': 'Caribe'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 145  {'M49': 662, 'ISO-ALPHA-2': 'LC', 'ISO-ALPHA-3': 'LCA'}                                     Santa Lúcia                              {'id': {'M49': 29}, 'nome': 'Caribe'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 146  {'M49': 670, 'ISO-ALPHA-2': 'VC', 'ISO-ALPHA-3': 'VCT'}                        São Vicente e Granadinas                              {'id': {'M49': 29}, 'nome': 'Caribe'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 147  {'M49': 674, 'ISO-ALPHA-2': 'SM', 'ISO-ALPHA-3': 'SMR'}                                      San Marino                                                               None      {'id': {'M49': 39}, 'nome': 'Europa meridional  (Sul da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 148  {'M49': 678, 'ISO-ALPHA-2': 'ST', 'ISO-ALPHA-3': 'STP'}                             São Tomé e Príncipe                      {'id': {'M49': 17}, 'nome': 'África central'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 149  {'M49': 682, 'ISO-ALPHA-2': 'SA', 'ISO-ALPHA-3': 'SAU'}                                  Arábia Saudita                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 150  {'M49': 686, 'ISO-ALPHA-2': 'SN', 'ISO-ALPHA-3': 'SEN'}                                         Senegal  {'id': {'M49': 11}, 'nome': 'África ocidental (Oeste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 151  {'M49': 688, 'ISO-ALPHA-2': 'RS', 'ISO-ALPHA-3': 'SRB'}                                          Sérvia                                                               None      {'id': {'M49': 39}, 'nome': 'Europa meridional  (Sul da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 152  {'M49': 690, 'ISO-ALPHA-2': 'SC', 'ISO-ALPHA-3': 'SYC'}                                      Seichelles   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 153  {'M49': 694, 'ISO-ALPHA-2': 'SL', 'ISO-ALPHA-3': 'SLE'}                                      Serra Leoa  {'id': {'M49': 11}, 'nome': 'África ocidental (Oeste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 154  {'M49': 702, 'ISO-ALPHA-2': 'SG', 'ISO-ALPHA-3': 'SGP'}                                       Singapura                                                               None                           {'id': {'M49': 35}, 'nome': 'Sudeste da Ásia', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 155  {'M49': 703, 'ISO-ALPHA-2': 'SK', 'ISO-ALPHA-3': 'SVK'}                                      Eslováquia                                                               None      {'id': {'M49': 151}, 'nome': 'Europa oriental (Leste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 156  {'M49': 704, 'ISO-ALPHA-2': 'VN', 'ISO-ALPHA-3': 'VNM'}                                          Vietnã                                                               None                           {'id': {'M49': 35}, 'nome': 'Sudeste da Ásia', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 157  {'M49': 705, 'ISO-ALPHA-2': 'SI', 'ISO-ALPHA-3': 'SVN'}                                       Eslovênia                                                               None      {'id': {'M49': 39}, 'nome': 'Europa meridional  (Sul da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 158  {'M49': 706, 'ISO-ALPHA-2': 'SO', 'ISO-ALPHA-3': 'SOM'}                                         Somália   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 159  {'M49': 710, 'ISO-ALPHA-2': 'ZA', 'ISO-ALPHA-3': 'ZAF'}                                   África do Sul   {'id': {'M49': 18}, 'nome': 'África meridional (Sul da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 160  {'M49': 716, 'ISO-ALPHA-2': 'ZW', 'ISO-ALPHA-3': 'ZWE'}                                        Zimbábue   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 161  {'M49': 724, 'ISO-ALPHA-2': 'ES', 'ISO-ALPHA-3': 'ESP'}                                         Espanha                                                               None      {'id': {'M49': 39}, 'nome': 'Europa meridional  (Sul da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 162  {'M49': 728, 'ISO-ALPHA-2': 'SS', 'ISO-ALPHA-3': 'SSD'}                                    Sudão do Sul   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 163  {'M49': 729, 'ISO-ALPHA-2': 'SD', 'ISO-ALPHA-3': 'SDN'}                                           Sudão                                                               None     {'id': {'M49': 15}, 'nome': 'África setentrional (Norte da África)', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 164  {'M49': 740, 'ISO-ALPHA-2': 'SR', 'ISO-ALPHA-3': 'SUR'}                                        Suriname                       {'id': {'M49': 5}, 'nome': 'América do sul'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 165  {'M49': 748, 'ISO-ALPHA-2': 'SZ', 'ISO-ALPHA-3': 'SWZ'}                                        Eswatini   {'id': {'M49': 18}, 'nome': 'África meridional (Sul da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 166  {'M49': 752, 'ISO-ALPHA-2': 'SE', 'ISO-ALPHA-3': 'SWE'}                                          Suécia                                                               None  {'id': {'M49': 154}, 'nome': 'Europa setentrional (Norte da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 167  {'M49': 756, 'ISO-ALPHA-2': 'CH', 'ISO-ALPHA-3': 'CHE'}                                           Suíça                                                               None     {'id': {'M49': 155}, 'nome': 'Europa ocidental (Oeste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 168  {'M49': 760, 'ISO-ALPHA-2': 'SY', 'ISO-ALPHA-3': 'SYR'}                                           Síria                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 169  {'M49': 762, 'ISO-ALPHA-2': 'TJ', 'ISO-ALPHA-3': 'TJK'}                                    Tadjiquistão                                                               None                             {'id': {'M49': 143}, 'nome': 'Ásia central', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 170  {'M49': 764, 'ISO-ALPHA-2': 'TH', 'ISO-ALPHA-3': 'THA'}                                       Tailândia                                                               None                           {'id': {'M49': 35}, 'nome': 'Sudeste da Ásia', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 171  {'M49': 768, 'ISO-ALPHA-2': 'TG', 'ISO-ALPHA-3': 'TGO'}                                            Togo  {'id': {'M49': 11}, 'nome': 'África ocidental (Oeste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 172  {'M49': 776, 'ISO-ALPHA-2': 'TO', 'ISO-ALPHA-3': 'TON'}                                           Tonga                                                               None                                {'id': {'M49': 61}, 'nome': 'Polinésia', 'regiao': {'id': {'M49': 9}, 'nome': 'Oceania'}}
# 173  {'M49': 780, 'ISO-ALPHA-2': 'TT', 'ISO-ALPHA-3': 'TTO'}                               Trinidad e Tobago                              {'id': {'M49': 29}, 'nome': 'Caribe'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 174  {'M49': 784, 'ISO-ALPHA-2': 'AE', 'ISO-ALPHA-3': 'ARE'}                          Emirados Árabes Unidos                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 175  {'M49': 788, 'ISO-ALPHA-2': 'TN', 'ISO-ALPHA-3': 'TUN'}                                         Tunísia                                                               None     {'id': {'M49': 15}, 'nome': 'África setentrional (Norte da África)', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 176  {'M49': 792, 'ISO-ALPHA-2': 'TR', 'ISO-ALPHA-3': 'TUR'}                                         Turquia                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 177  {'M49': 795, 'ISO-ALPHA-2': 'TM', 'ISO-ALPHA-3': 'TKM'}                                   Turcomenistão                                                               None                             {'id': {'M49': 143}, 'nome': 'Ásia central', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 178  {'M49': 798, 'ISO-ALPHA-2': 'TV', 'ISO-ALPHA-3': 'TUV'}                                          Tuvalu                                                               None                                {'id': {'M49': 61}, 'nome': 'Polinésia', 'regiao': {'id': {'M49': 9}, 'nome': 'Oceania'}}
# 179  {'M49': 800, 'ISO-ALPHA-2': 'UG', 'ISO-ALPHA-3': 'UGA'}                                          Uganda   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 180  {'M49': 804, 'ISO-ALPHA-2': 'UA', 'ISO-ALPHA-3': 'UKR'}                                         Ucrânia                                                               None      {'id': {'M49': 151}, 'nome': 'Europa oriental (Leste da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 181  {'M49': 807, 'ISO-ALPHA-2': 'MK', 'ISO-ALPHA-3': 'MKD'}                              Macedônia do Norte                                                               None      {'id': {'M49': 39}, 'nome': 'Europa meridional  (Sul da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 182  {'M49': 818, 'ISO-ALPHA-2': 'EG', 'ISO-ALPHA-3': 'EGY'}                                           Egito                                                               None     {'id': {'M49': 15}, 'nome': 'África setentrional (Norte da África)', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 183  {'M49': 826, 'ISO-ALPHA-2': 'GB', 'ISO-ALPHA-3': 'GBR'}  Reino Unido da Grã-Bretanha e Irlanda do Norte                                                               None  {'id': {'M49': 154}, 'nome': 'Europa setentrional (Norte da Europa)', 'regiao': {'id': {'M49': 150}, 'nome': 'Europa'}}
# 184  {'M49': 834, 'ISO-ALPHA-2': 'TZ', 'ISO-ALPHA-3': 'TZA'}                    Tanzânia, República Unida da   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 185  {'M49': 840, 'ISO-ALPHA-2': 'US', 'ISO-ALPHA-3': 'USA'}                       Estados Unidos da América                                                               None                        {'id': {'M49': 21}, 'nome': 'América do Norte', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 186  {'M49': 854, 'ISO-ALPHA-2': 'BF', 'ISO-ALPHA-3': 'BFA'}                                    Burkina Faso  {'id': {'M49': 11}, 'nome': 'África ocidental (Oeste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
# 187  {'M49': 858, 'ISO-ALPHA-2': 'UY', 'ISO-ALPHA-3': 'URY'}                                         Uruguai                       {'id': {'M49': 5}, 'nome': 'América do sul'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 188  {'M49': 860, 'ISO-ALPHA-2': 'UZ', 'ISO-ALPHA-3': 'UZB'}                                     Uzbequistão                                                               None                             {'id': {'M49': 143}, 'nome': 'Ásia central', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 189  {'M49': 862, 'ISO-ALPHA-2': 'VE', 'ISO-ALPHA-3': 'VEN'}            Venezuela (República Bolivariana da)                       {'id': {'M49': 5}, 'nome': 'América do sul'}                {'id': {'M49': 419}, 'nome': 'América Latina e Caribe', 'regiao': {'id': {'M49': 19}, 'nome': 'América'}}
# 190  {'M49': 882, 'ISO-ALPHA-2': 'WS', 'ISO-ALPHA-3': 'WSM'}                                           Samoa                                                               None                                {'id': {'M49': 61}, 'nome': 'Polinésia', 'regiao': {'id': {'M49': 9}, 'nome': 'Oceania'}}
# 191  {'M49': 887, 'ISO-ALPHA-2': 'YE', 'ISO-ALPHA-3': 'YEM'}                                           Iêmen                                                               None          {'id': {'M49': 145}, 'nome': 'Ásia ocidental  (Oeste da Ásia)', 'regiao': {'id': {'M49': 142}, 'nome': 'Ásia'}}
# 192  {'M49': 894, 'ISO-ALPHA-2': 'ZM', 'ISO-ALPHA-3': 'ZMB'}                                          Zâmbia   {'id': {'M49': 14}, 'nome': 'África oriental (Leste da África)'}                       {'id': {'M49': 202}, 'nome': 'África subsaariana', 'regiao': {'id': {'M49': 2}, 'nome': 'África'}}
