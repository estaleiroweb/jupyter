# %% [markdown]
# # Carregamento de imagens

# %% [markdown]
# ## Usando Markdown:
#
# ![Descrição da imagem](image.jpg)
#
# Video:
#
# <video width="320" height="240" controls>
#   <source src="video.mp4" type="video/mp4">
# </video>
#
# Youtube Link:
#
# [![](https://markdown-videos-api.jorgenkh.no/youtube/PV4mcLn9WIw)](https://youtu.be/PV4mcLn9WIw)

# %% [markdown]
# ## Usando código:

# %%
from IPython.display import Image, display
display(Image(filename='image.jpg',width=300))

# %%
from IPython.display import Video
Video("video.mp4")
# Out:
# <video src="video.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Anexando:
#
# Clique no [...] - Edit Slide Type JSON:
#
# ```json
#  {
#    "attachments": {
#     "name_of_file.png": {
#      "image/png": "base64_image"
#     }
#    },
#    "cell_type": "markdown",
#    "id": "4385280c",
#    "metadata": {},
#    "source": [
#     "![name_of_file.png](attachment:name_of_file.png)"
#    ]
#   }
#
# ```
#
#
# ![image.png](attachment:image.png)
#
# Ou no Jupyter Notebook: https://www-geeksforgeeks-org.translate.goog/insert-image-in-a-jupyter-notebook/?_x_tr_sl=en&_x_tr_tl=pt&_x_tr_hl=pt&_x_tr_pto=wa

# %% [markdown]
# In Rocchio model, the prediction is based on the similarity (e.g., cosine) between items and users:
#
# - Each item is a vector of features _(similar to features-matrix)_
# - Each user is a mix of his/her items consumed:
# ![image.png](attachment:image.png)
