# %% [markdown]
# # Declarações de Gerenciamento de Contexto
#
# ## `with` → Gerencia recursos automaticamente (exemplo: arquivos)

# %%
with open("09_with.ipynb", "r") as f:
    conteudo = f.read()

print(conteudo)
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# DeclaraÃ§Ãµes de Gerenciamento de Contexto\n",
#     "\n",
#     "## `with` â†’ Gerencia recursos automaticamente (exemplo: arquivos)"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 2,
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "{\n",
#       " \"cells\": [\n",
#       "  {\n",
#       "   \"cell_type\": \"markdown\",\n",
#       "   \"metadata\": {},\n",
#       "   \"source\": [\n",
#       "    \"# DeclaraÃƒÂ§ÃƒÂµes de Gerenciamento de Contexto\\n\",\n",
#       "    \"\\n\",\n",
#       "    \"## `with` Ã¢â€ â€™ Gerencia recursos automaticamente (exemplo: arquivos)\"\n",
#       "   ]\n",
#       "  },\n",
#       "  {\n",
#       "   \"cell_type\": \"code\",\n",
#       "   \"execution_count\": 1,\n",
#       "   \"metadata\": {},\n",
#       "   \"outputs\": [\n",
# ...
